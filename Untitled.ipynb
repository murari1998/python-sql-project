# %%
import pandas as pd
import mysql.connector
import os

# List of CSV files and their corresponding table names
csv_files = [
    ('customers.csv', 'customers'),
    ('orders.csv', 'orders'),
    ('sellers.csv', 'sellers'),
    ('products.csv', 'products'),
    ('geolocation.csv', 'geolocation'),
    ('payments.csv', 'payments'),
    ('order_items.csv','order_items')# Added payments.csv for specific handling
]

# Connect to the MySQL database
conn = mysql.connector.connect(
    host='localhost',
    user='root',
    password='Msaini1998@',
    database='ecommarce'
)
cursor = conn.cursor()

# Folder containing the CSV files
folder_path = 'C:/Users/Murari Saini/OneDrive/Desktop/e-commerce'

def get_sql_type(dtype):
    if pd.api.types.is_integer_dtype(dtype):
        return 'INT'
    elif pd.api.types.is_float_dtype(dtype):
        return 'FLOAT'
    elif pd.api.types.is_bool_dtype(dtype):
        return 'BOOLEAN'
    elif pd.api.types.is_datetime64_any_dtype(dtype):
        return 'DATETIME'
    else:
        return 'TEXT'

for csv_file, table_name in csv_files:
    file_path = os.path.join(folder_path, csv_file)
    
    # Read the CSV file into a pandas DataFrame
    df = pd.read_csv(file_path)
    
    # Replace NaN with None to handle SQL NULL
    df = df.where(pd.notnull(df), None)
    
    # Debugging: Check for NaN values
    print(f"Processing {csv_file}")
    print(f"NaN values before replacement:\n{df.isnull().sum()}\n")

    # Clean column names
    df.columns = [col.replace(' ', '_').replace('-', '_').replace('.', '_') for col in df.columns]

    # Generate the CREATE TABLE statement with appropriate data types
    columns = ', '.join([f'`{col}` {get_sql_type(df[col].dtype)}' for col in df.columns])
    create_table_query = f'CREATE TABLE IF NOT EXISTS `{table_name}` ({columns})'
    cursor.execute(create_table_query)

    # Insert DataFrame data into the MySQL table
    for _, row in df.iterrows():
        # Convert row to tuple and handle NaN/None explicitly
        values = tuple(None if pd.isna(x) else x for x in row)
        sql = f"INSERT INTO `{table_name}` ({', '.join(['`' + col + '`' for col in df.columns])}) VALUES ({', '.join(['%s'] * len(row))})"
        cursor.execute(sql, values)

    # Commit the transaction for the current CSV file
    conn.commit()

# Close the connection
conn.close()
# Out:
# Processing customers.csv
# NaN values before replacement:
# customer_id                 0
# customer_unique_id          0
# customer_zip_code_prefix    0
# customer_city               0
# customer_state              0
# dtype: int64
#
# Processing orders.csv
# NaN values before replacement:
# order_id                            0
# customer_id                         0
# order_status                        0
# order_purchase_timestamp            0
# order_approved_at                 160
# order_delivered_carrier_date     1783
# order_delivered_customer_date    2965
# order_estimated_delivery_date       0
# dtype: int64
#
# Processing sellers.csv
# NaN values before replacement:
# seller_id                 0
# seller_zip_code_prefix    0
# seller_city               0
# seller_state              0
# dtype: int64
#
# Processing products.csv
# NaN values before replacement:
# product_id                      0
# product category              610
# product_name_length           610
# product_description_length    610
# product_photos_qty            610
# product_weight_g                2
# product_length_cm               2
# product_height_cm               2
# product_width_cm                2
# dtype: int64
#
# Processing geolocation.csv
# NaN values before replacement:
# geolocation_zip_code_prefix    0
# geolocation_lat                0
# geolocation_lng                0
# geolocation_city               0
# geolocation_state              0
# dtype: int64
#
# Processing payments.csv
# NaN values before replacement:
# order_id                0
# payment_sequential      0
# payment_type            0
# payment_installments    0
# payment_value           0
# dtype: int64
#
# Processing order_items.csv
# NaN values before replacement:
# order_id               0
# order_item_id          0
# product_id             0
# seller_id              0
# shipping_limit_date    0
# price                  0
# freight_value          0
# dtype: int64

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import mysql.connector

db=mysql.connector.connect(host="localhost",
                           username="root",
                           password="Msaini1998@",
                           database="ecommarce")



cur=db.cursor()

# %% [markdown]
# # .  List all unique cities where customers are located.

# %%
query="""select distinct customer_city from customers """

cur.execute(query)
data=cur.fetchall()

data
# Out:
# [('franca',),
#  ('sao bernardo do campo',),
#  ('sao paulo',),
#  ('mogi das cruzes',),
#  ('campinas',),
#  ('jaragua do sul',),
#  ('timoteo',),
#  ('curitiba',),
#  ('belo horizonte',),
#  ('montes claros',),
#  ('rio de janeiro',),
#  ('lencois paulista',),
#  ('caxias do sul',),
#  ('piracicaba',),
#  ('guarulhos',),
#  ('pacaja',),
#  ('florianopolis',),
#  ('aparecida de goiania',),
#  ('santo andre',),
#  ('goiania',),
#  ('cachoeiro de itapemirim',),
#  ('sao jose dos campos',),
#  ('sao roque',),
#  ('camacari',),
#  ('resende',),
#  ('sumare',),
#  ('novo hamburgo',),
#  ('sao luis',),
#  ('sao jose',),
#  ('santa barbara',),
#  ('ribeirao preto',),
#  ('ituiutaba',),
#  ('taquarituba',),
#  ('sao jose dos pinhais',),
#  ('barrinha',),
#  ('parati',),
#  ('dourados',),
#  ('trindade',),
#  ('cascavel',),
#  ('fortaleza',),
#  ('brasilia',),
#  ('pelotas',),
#  ('porto alegre',),
#  ('salto',),
#  ('jundiai',),
#  ('cacapava',),
#  ('sao vicente',),
#  ('uberlandia',),
#  ('botelhos',),
#  ('sao goncalo',),
#  ('araucaria',),
#  ('nova iguacu',),
#  ('areia branca',),
#  ('campos dos goytacazes',),
#  ('sao carlos',),
#  ('itajuba',),
#  ('cruz das almas',),
#  ('vassouras',),
#  ('feira de santana',),
#  ('niteroi',),
#  ('sobral',),
#  ('divinopolis',),
#  ('paraiba do sul',),
#  ('paulista',),
#  ('carapicuiba',),
#  ('bom principio',),
#  ('astolfo dutra',),
#  ('marialva',),
#  ('sao jose do rio preto',),
#  ('cabo frio',),
#  ('contagem',),
#  ('cafeara',),
#  ('sao joaquim da barra',),
#  ('foz do iguacu',),
#  ('suzano',),
#  ('timbo',),
#  ('camboriu',),
#  ('nova bassano',),
#  ('rio grande',),
#  ('braganca paulista',),
#  ('barra do garcas',),
#  ('embu',),
#  ('urussanga',),
#  ('silvianopolis',),
#  ('gameleiras',),
#  ('belem',),
#  ('pocos de caldas',),
#  ('santos',),
#  ('piracaia',),
#  ('sinop',),
#  ('guaruja',),
#  ('barueri',),
#  ('feliz',),
#  ('jambeiro',),
#  ('ipatinga',),
#  ('tupa',),
#  ('blumenau',),
#  ('moncoes',),
#  ('balneario camboriu',),
#  ('vargem grande',),
#  ('rio brilhante',),
#  ('eugenopolis',),
#  ('paulinia',),
#  ('apucarana',),
#  ('recife',),
#  ('osasco',),
#  ('valinhos',),
#  ('manaus',),
#  ('cidreira',),
#  ('santiago',),
#  ('sao sepe',),
#  ('alta floresta',),
#  ('jaboatao dos guararapes',),
#  ('ibatiba',),
#  ('hortolandia',),
#  ('cotia',),
#  ('macae',),
#  ('saudades',),
#  ('macapa',),
#  ('salto de pirapora',),
#  ('taboao da serra',),
#  ('bom jesus',),
#  ('santa cruz do rio pardo',),
#  ('diadema',),
#  ('santa ines',),
#  ('serrinha',),
#  ('votorantim',),
#  ('itatiaia',),
#  ('duque de caxias',),
#  ('varre-sai',),
#  ('vila velha',),
#  ('mangaratiba',),
#  ('atibaia',),
#  ('salvador',),
#  ('maceio',),
#  ('birigui',),
#  ('petropolis',),
#  ('sao pedro',),
#  ('jaguariaiva',),
#  ('franco da rocha',),
#  ('pindamonhangaba',),
#  ('irati',),
#  ('ribeira',),
#  ('barbacena',),
#  ('limoeiro',),
#  ('espigao do oeste',),
#  ('belford roxo',),
#  ('coronel fabriciano',),
#  ('itanhaem',),
#  ('bebedouro',),
#  ('americana',),
#  ('uba',),
#  ('arapongas',),
#  ('vinhedo',),
#  ('itajai',),
#  ('bauru',),
#  ('pradopolis',),
#  ('aripuana',),
#  ('guaratinga',),
#  ('ponta pora',),
#  ('aracatuba',),
#  ('volta redonda',),
#  ('maringa',),
#  ('araraquara',),
#  ('matipo',),
#  ('santo antonio da patrulha',),
#  ('barra mansa',),
#  ('diamantina',),
#  ('mairinque',),
#  ('capitao leonidas marques',),
#  ('sao sebastiao do paraiso',),
#  ('rosario do sul',),
#  ('itaguai',),
#  ('paraopeba',),
#  ('guarapuava',),
#  ('crisolita',),
#  ('pirai',),
#  ('linhares',),
#  ('agudos',),
#  ('sao joao de meriti',),
#  ('navegantes',),
#  ('pirassununga',),
#  ('faxinal dos guedes',),
#  ('criciuma',),
#  ('nova venecia',),
#  ('passo fundo',),
#  ('ibia',),
#  ('manhuacu',),
#  ('altamira',),
#  ('aperibe',),
#  ('cuiaba',),
#  ('canoas',),
#  ('cubatao',),
#  ('campo limpo paulista',),
#  ('cambe',),
#  ('itaquaquecetuba',),
#  ('sao caetano do sul',),
#  ('sao goncalo do rio abaixo',),
#  ('rolandia',),
#  ('tres coracoes',),
#  ('cacapava do sul',),
#  ('sao joao nepomuceno',),
#  ('leme',),
#  ('araras',),
#  ('cortes',),
#  ('brusque',),
#  ('montenegro',),
#  ('itaberai',),
#  ('santa rosa de viterbo',),
#  ('agua fria de goias',),
#  ('marau',),
#  ('curvelo',),
#  ('juiz de fora',),
#  ('mogi-guacu',),
#  ('guaratingueta',),
#  ('paranagua',),
#  ('lins',),
#  ('campo bom',),
#  ('sertaozinho',),
#  ('tres lagoas',),
#  ('jau',),
#  ('campos de julio',),
#  ('saquarema',),
#  ('artur nogueira',),
#  ('uaua',),
#  ('jandira',),
#  ('concordia',),
#  ('nova friburgo',),
#  ('sorocaba',),
#  ('ponte nova',),
#  ('araquari',),
#  ('muriae',),
#  ('nova lima',),
#  ('inhumas',),
#  ('italva',),
#  ('tres rios',),
#  ('santa maria',),
#  ('itagiba',),
#  ('paracatu',),
#  ('xaxim',),
#  ('laranjeiras do sul',),
#  ('itapiuna',),
#  ('formosa',),
#  ('ivoti',),
#  ('juazeiro',),
#  ('ponta grossa',),
#  ('campina grande',),
#  ('maua',),
#  ('salgueiro',),
#  ('lorena',),
#  ('toledo',),
#  ('sao pedro da aldeia',),
#  ('vianopolis',),
#  ('arapiraca',),
#  ('porto seguro',),
#  ('ariquemes',),
#  ('presidente getulio',),
#  ('rio negro',),
#  ('ribeirao pires',),
#  ('sao jose da coroa grande',),
#  ('agua doce do norte',),
#  ('anapolis',),
#  ('guararapes',),
#  ('farroupilha',),
#  ('almenara',),
#  ('rio das ostras',),
#  ('gravatai',),
#  ('brumado',),
#  ('marilia',),
#  ('itabira',),
#  ('claudia',),
#  ('para de minas',),
#  ('miguelopolis',),
#  ('terra roxa',),
#  ('araguari',),
#  ('lages',),
#  ('embu das artes',),
#  ('limeira',),
#  ('taubate',),
#  ('santa fe do sul',),
#  ('caieiras',),
#  ('carangola',),
#  ('chapada do norte',),
#  ('loanda',),
#  ('passa tres',),
#  ('aracoiaba da serra',),
#  ('itaborai',),
#  ('vitoria',),
#  ('sao bento do sul',),
#  ('indaiatuba',),
#  ('boituva',),
#  ('teresopolis',),
#  ('pinhalzinho',),
#  ('petrolina',),
#  ('natal',),
#  ('barreiras',),
#  ('januaria',),
#  ('ipiabas',),
#  ('firminopolis',),
#  ('joinville',),
#  ('mococa',),
#  ('valenca',),
#  ('sao miguel do oeste',),
#  ('jales',),
#  ('rio formoso',),
#  ('angra dos reis',),
#  ('alfredo chaves',),
#  ('itapetinga',),
#  ('gurupi',),
#  ('nucleo residencial pilar',),
#  ('coromandel',),
#  ('charqueada',),
#  ('itau de minas',),
#  ('ibiruba',),
#  ('bertioga',),
#  ('ipiau',),
#  ('matozinhos',),
#  ('teresina',),
#  ('entre rios',),
#  ('juina',),
#  ('mairipora',),
#  ('marechal candido rondon',),
#  ('avare',),
#  ('icem',),
#  ('sao sebastiao',),
#  ('serra',),
#  ('mirassol',),
#  ('taperuaba',),
#  ('alfenas',),
#  ('leopoldina',),
#  ('sao joao da boa vista',),
#  ('parnamirim',),
#  ('teixeira de freitas',),
#  ('joao pessoa',),
#  ('chacara',),
#  ('rio novo do sul',),
#  ('guapore',),
#  ('rio branco',),
#  ('ferraz de vasconcelos',),
#  ('petrolandia',),
#  ('araruna',),
#  ('gravata',),
#  ('alegre',),
#  ('londrina',),
#  ('senhor do bonfim',),
#  ('santana de parnaiba',),
#  ('piratininga',),
#  ('monte carmelo',),
#  ('ipiranga',),
#  ('jacarei',),
#  ('picos',),
#  ('una',),
#  ('taguai',),
#  ('peabiru',),
#  ('conquista',),
#  ('bicas',),
#  ('forquilha',),
#  ('guaicara',),
#  ('santa vitoria',),
#  ('adamantina',),
#  ('rio claro',),
#  ('sao jose de uba',),
#  ('sorriso',),
#  ('aracaju',),
#  ('conselheiro lafaiete',),
#  ('taguatinga',),
#  ('tiangua',),
#  ('paranaiba',),
#  ('david canabarro',),
#  ('itarare',),
#  ('cajueiro',),
#  ('cruzeiro',),
#  ('santa cruz do sul',),
#  ('presidente epitacio',),
#  ('castanhal',),
#  ('cariacica',),
#  ('bom jesus dos perdoes',),
#  ('urucurituba',),
#  ('olinda',),
#  ('sao jose do rio pardo',),
#  ('guapimirim',),
#  ('vargem grande paulista',),
#  ('chapeco',),
#  ('videira',),
#  ('canapi',),
#  ('pontal do parana',),
#  ('bento goncalves',),
#  ('caceres',),
#  ('bituruna',),
#  ('sao bento do sapucai',),
#  ('mage',),
#  ('forquilhinha',),
#  ('itaberaba',),
#  ('gramado',),
#  ('guacui',),
#  ('pato branco',),
#  ('itanhem',),
#  ('palmas',),
#  ('bage',),
#  ('francisco morato',),
#  ('cosmopolis',),
#  ('carmo',),
#  ('armacao dos buzios',),
#  ('santa maria da vitoria',),
#  ('pedro leopoldo',),
#  ('tres marias',),
#  ('santo antonio de padua',),
#  ('porto feliz',),
#  ('gaspar',),
#  ('palhoca',),
#  ('pouso alegre',),
#  ('guaiuba',),
#  ('fraiburgo',),
#  ('aurea',),
#  ('botucatu',),
#  ('corumba',),
#  ('cajamar',),
#  ('queimados',),
#  ('sao jorge do ivai',),
#  ('nova laranjeiras',),
#  ('guaxupe',),
#  ('osvaldo cruz',),
#  ('ivora',),
#  ('anaurilandia',),
#  ('caraguatatuba',),
#  ('regeneracao',),
#  ('bilac',),
#  ('faxinal',),
#  ('pedro velho',),
#  ('uberaba',),
#  ('viamao',),
#  ('cachoeira de minas',),
#  ('coelho neto',),
#  ('itajobi',),
#  ('carmo do rio claro',),
#  ('marica',),
#  ('campo novo do parecis',),
#  ('boa vista',),
#  ('ipameri',),
#  ('carlos barbosa',),
#  ('anicuns',),
#  ('rio bananal',),
#  ('lavras da mangabeira',),
#  ('balsamo',),
#  ('guariba',),
#  ('sao vendelino',),
#  ('campo mourao',),
#  ('aracati',),
#  ('santo antonio do descoberto',),
#  ('santo amaro da imperatriz',),
#  ('betim',),
#  ('vicosa',),
#  ('dom eliseu',),
#  ('campo largo',),
#  ('santa rosa de lima',),
#  ('quissama',),
#  ('mirandopolis',),
#  ('itapevi',),
#  ('francisco beltrao',),
#  ("dias d'avila",),
#  ('novo horizonte',),
#  ('poa',),
#  ('querencia',),
#  ('campo grande',),
#  ('pedreira',),
#  ('pariquera-acu',),
#  ('itabaianinha',),
#  ('pitangui',),
#  ('araruama',),
#  ('campo formoso',),
#  ('guanambi',),
#  ('itapolis',),
#  ('pederneiras',),
#  ('itabirito',),
#  ('itaipava',),
#  ('arroio do sal',),
#  ('glaura',),
#  ('lagoa vermelha',),
#  ('mantena',),
#  ('peruibe',),
#  ('tubarao',),
#  ('bonfim',),
#  ('alvorada',),
#  ('patrocinio',),
#  ('mineiros',),
#  ('itabuna',),
#  ('tijucas',),
#  ('santo antonio de jesus',),
#  ('canarana',),
#  ('itapecerica da serra',),
#  ('nova prata do iguacu',),
#  ('treze tilias',),
#  ('anchieta',),
#  ('quatigua',),
#  ('iturama',),
#  ('tres de maio',),
#  ('santa rita do passa quatro',),
#  ('porto esperidiao',),
#  ('bonfim paulista',),
#  ('cajuru',),
#  ('cacador',),
#  ('paragominas',),
#  ('boa esperanca do sul',),
#  ('tres pontas',),
#  ('juazeiro do norte',),
#  ('bambui',),
#  ('comendador levy gasparian',),
#  ('sao miguel do aleixo',),
#  ('palmeira dos indios',),
#  ('cerquilho',),
#  ('saudade do iguacu',),
#  ('ipaussu',),
#  ('alto paraiso de goias',),
#  ('santa isabel',),
#  ('quirinopolis',),
#  ('caruaru',),
#  ('casimiro de abreu',),
#  ('chavantes',),
#  ('ecoporanga',),
#  ('cachoeira paulista',),
#  ('rio verde',),
#  ('maracanau',),
#  ('canoinhas',),
#  ('ituverava',),
#  ('buriti dos lopes',),
#  ('rio do antonio',),
#  ('guaranta',),
#  ('santa luzia',),
#  ('tucurui',),
#  ('paranavai',),
#  ('pinhais',),
#  ('governador valadares',),
#  ('trajano de moraes',),
#  ('caete',),
#  ('abaetetuba',),
#  ('lavras',),
#  ('coronel joao sa',),
#  ('divino',),
#  ('macaubas',),
#  ('lucelia',),
#  ('brejo da madre de deus',),
#  ('carai',),
#  ('corbelia',),
#  ('varginha',),
#  ('ouro preto',),
#  ('prado',),
#  ('colniza',),
#  ('piuma',),
#  ('rancharia',),
#  ('barretos',),
#  ('eunapolis',),
#  ('floresta',),
#  ('sao jose do norte',),
#  ('rio bonito',),
#  ('vargem bonita',),
#  ('monte mor',),
#  ('valente',),
#  ('balsas',),
#  ('nhandeara',),
#  ('lauro de freitas',),
#  ('osorio',),
#  ('machado',),
#  ('sao leopoldo',),
#  ('soledade',),
#  ('assis',),
#  ('guarapari',),
#  ('santo antonio do caiua',),
#  ('esteio',),
#  ('cambuci',),
#  ('campina grande do sul',),
#  ('baixo guandu',),
#  ('fernao',),
#  ('ibitinga',),
#  ('santa cruz das palmeiras',),
#  ('vila muriqui',),
#  ('sao mateus',),
#  ('piracuruca',),
#  ('cordeiro',),
#  ('cachoeira do sul',),
#  ('barra do pirai',),
#  ('castro',),
#  ('ico',),
#  ('sete lagoas',),
#  ('itumbiara',),
#  ('aluminio',),
#  ('jatai',),
#  ('frederico westphalen',),
#  ('goioere',),
#  ('sao jose da tapera',),
#  ('porto uniao',),
#  ('cocalinho',),
#  ('curitibanos',),
#  ('campos novos',),
#  ('ubatuba',),
#  ('monte santo de minas',),
#  ('ribeirao das neves',),
#  ('sao simao',),
#  ('urutai',),
#  ('itaobim',),
#  ('liberdade',),
#  ('arcos',),
#  ('ribeirao',),
#  ('patos de minas',),
#  ('penapolis',),
#  ('eusebio',),
#  ('cordeiros',),
#  ('victor graeff',),
#  ('santa rita do araguaia',),
#  ('poxoreu',),
#  ('ananas',),
#  ('conceicao dos ouros',),
#  ('alagoinhas',),
#  ('sao joao da barra',),
#  ('lindoia',),
#  ('bonfinopolis',),
#  ('ibiam',),
#  ('morungaba',),
#  ('andradina',),
#  ('tatui',),
#  ('mata verde',),
#  ('cornelio procopio',),
#  ('itapipoca',),
#  ('queluz',),
#  ('godoy moreira',),
#  ('iracemapolis',),
#  ('buritizeiro',),
#  ('xique-xique',),
#  ('uruacu',),
#  ('japi',),
#  ('itauna',),
#  ('sao francisco de assis',),
#  ('pitangueiras',),
#  ('ze doca',),
#  ('dracena',),
#  ('cachoeiras de macacu',),
#  ('barauna',),
#  ('formiga',),
#  ('rodeio',),
#  ('jequie',),
#  ('juvenilia',),
#  ('poco fundo',),
#  ('amparo',),
#  ('lauro muller',),
#  ('japeri',),
#  ('ourinhos',),
#  ('lagoa dos gatos',),
#  ('embu-guacu',),
#  ('nossa senhora do remedio',),
#  ('tambau',),
#  ('orlandia',),
#  ('bananeiras',),
#  ('sao joao do manhuacu',),
#  ('sarandi',),
#  ('congonhas',),
#  ('boa esperanca',),
#  ('sandolandia',),
#  ('garca',),
#  ('descalvado',),
#  ('guaracai',),
#  ('aruana',),
#  ('inga',),
#  ('taio',),
#  ('gaurama',),
#  ('praia grande',),
#  ('janauba',),
#  ('nova monte verde',),
#  ('mongagua',),
#  ('monte alto',),
#  ('sao joao do piaui',),
#  ('primavera do leste',),
#  ('seropedica',),
#  ('indaial',),
#  ('teofilo otoni',),
#  ('santa terezinha',),
#  ('planaltina',),
#  ('caravelas',),
#  ('muritiba',),
#  ('itatiba',),
#  ('piumhii',),
#  ('pitanga',),
#  ('capelinha',),
#  ('ipero',),
#  ('tarabai',),
#  ('aparecida do taboado',),
#  ('maioba',),
#  ('monnerat',),
#  ('sao lourenco do sul',),
#  ('biguacu',),
#  ('venda nova do imigrante',),
#  ('arapoti',),
#  ('fazenda rio grande',),
#  ('senges',),
#  ('aracruz',),
#  ('canela',),
#  ('porto franco',),
#  ('veranopolis',),
#  ('candiota',),
#  ('carmo do paranaiba',),
#  ('itacare',),
#  ('desembargador otoni',),
#  ('joanopolis',),
#  ('registro',),
#  ('ipiranga do norte',),
#  ('felipe guerra',),
#  ('dumont',),
#  ('itapetininga',),
#  ('bom despacho',),
#  ('lagoa santa',),
#  ('estacao',),
#  ('panorama',),
#  ('palmares',),
#  ('prata',),
#  ('santa adelia',),
#  ('iguaba grande',),
#  ('sarzedo',),
#  ('dourado',),
#  ('alcinopolis',),
#  ('limoeiro do norte',),
#  ('ibiraci',),
#  ('ilhabela',),
#  ('icara',),
#  ('paiva',),
#  ('batatais',),
#  ('formoso do araguaia',),
#  ('itapaci',),
#  ('fernandopolis',),
#  ('miguel pereira',),
#  ('tocos',),
#  ('campos do jordao',),
#  ('catalao',),
#  ('sao jose da lapa',),
#  ('marituba',),
#  ('arapora',),
#  ('turvo',),
#  ('rubiataba',),
#  ('guaruja do sul',),
#  ('pedra bela',),
#  ('perdizes',),
#  ('jesuania',),
#  ('antonio carlos',),
#  ('itapecerica',),
#  ('monte belo',),
#  ('mossoro',),
#  ('piraju',),
#  ('encruzilhada do sul',),
#  ('igaratinga',),
#  ('sao luis de montes belos',),
#  ('santa rosa',),
#  ('lagoinha',),
#  ('redentora',),
#  ('cuite',),
#  ('coxim',),
#  ('lucas do rio verde',),
#  ('ibirataia',),
#  ('olimpia',),
#  ('cedro',),
#  ('mario campos',),
#  ('umuarama',),
#  ('nova xavantina',),
#  ('sao borja',),
#  ('aguai',),
#  ('itapira',),
#  ('uniao da vitoria',),
#  ('nova odessa',),
#  ('itapuranga',),
#  ('nova cruz',),
#  ('apuiares',),
#  ('almirante tamandare',),
#  ('correia pinto',),
#  ('itamarandiba',),
#  ('juscimeira',),
#  ('ipora',),
#  ('cedro de sao joao',),
#  ("santa barbara d'oeste",),
#  ('sao joao da urtiga',),
#  ('valparaiso de goias',),
#  ('jussara',),
#  ('capao da canoa',),
#  ('araxa',),
#  ('campo belo',),
#  ('monte aprazivel',),
#  ('bom jesus do querendo',),
#  ('socorro',),
#  ('catanduva',),
#  ('monte castelo',),
#  ('tabatinga',),
#  ('bayeux',),
#  ('ijui',),
#  ('tangara da serra',),
#  ('campos borges',),
#  ('palma',),
#  ('minacu',),
#  ('miracema',),
#  ('taruma',),
#  ('sao francisco do sul',),
#  ('cedral',),
#  ('camaragibe',),
#  ('lajeado',),
#  ('cerqueira cesar',),
#  ('frutal',),
#  ('igarata',),
#  ('novo gama',),
#  ('sapucaia do sul',),
#  ('juquitiba',),
#  ('terra boa',),
#  ('joao monlevade',),
#  ('porangatu',),
#  ('formosa da serra negra',),
#  ('rafard',),
#  ('rainha do mar',),
#  ('pontal',),
#  ('rio do sul',),
#  ('nilopolis',),
#  ('maracaju',),
#  ('santo augusto',),
#  ('banabuiu',),
#  ('buenopolis',),
#  ('barbalha',),
#  ('quintana',),
#  ('chorrocho',),
#  ('votuporanga',),
#  ('poco verde',),
#  ('cipo-guacu',),
#  ('santarem',),
#  ('santa clara do sul',),
#  ('ibiuna',),
#  ('capivari',),
#  ('arraias',),
#  ('patos',),
#  ('sao francisco do guapore',),
#  ('vitoria da conquista',),
#  ('urucuca',),
#  ('vacaria',),
#  ('campos altos',),
#  ('nossa senhora do socorro',),
#  ('cruzeiro do sul',),
#  ('cataguases',),
#  ('varzea grande',),
#  ('santa rita do sapucai',),
#  ('jaboticabal',),
#  ('ilha comprida',),
#  ('brasilia de minas',),
#  ('moreno',),
#  ('capanema',),
#  ('tombos',),
#  ('espumoso',),
#  ('ouro branco',),
#  ('valenca do piaui',),
#  ('igrejinha',),
#  ('engenheiro coelho',),
#  ('parauapebas',),
#  ('afonso claudio',),
#  ('sao bernardo',),
#  ('salto do jacui',),
#  ('pires do rio',),
#  ('astorga',),
#  ('medina',),
#  ('porto ferreira',),
#  ('aracariguama',),
#  ('hidrolandia',),
#  ('virginopolis',),
#  ('soledade de minas',),
#  ('casca',),
#  ('sapiranga',),
#  ('angatuba',),
#  ('ibirapua',),
#  ('itupeva',),
#  ('espera feliz',),
#  ('penedo',),
#  ('ibirite',),
#  ('miracatu',),
#  ('francisco santos',),
#  ('paracambi',),
#  ('cardoso',),
#  ('floriano',),
#  ('rondonopolis',),
#  ('barra de sao francisco',),
#  ('lavinia',),
#  ('guajara-mirim',),
#  ('guimaraes',),
#  ('sao tome',),
#  ('medianeira',),
#  ('conceicao das pedras',),
#  ('rinopolis',),
#  ('capim grosso',),
#  ('guaira',),
#  ('euclides da cunha paulista',),
#  ('lagoa da prata',),
#  ('nanuque',),
#  ('luis antonio',),
#  ('senador firmino',),
#  ('viradouro',),
#  ('itabera',),
#  ('cambara',),
#  ('sananduva',),
#  ('tapera',),
#  ('tupaciguara',),
#  ('colombo',),
#  ('ananindeua',),
#  ('coribe',),
#  ('rio doce',),
#  ('mogi mirim',),
#  ('tocos do moji',),
#  ('beberibe',),
#  ('formosa do rio preto',),
#  ('claudio',),
#  ('rio paranaiba',),
#  ('humberto de campos',),
#  ('camocim de sao felix',),
#  ('santo antonio de posse',),
#  ('mesquita',),
#  ('passa quatro',),
#  ('belo oriente',),
#  ('alto araguaia',),
#  ('igarassu',),
#  ('porto velho',),
#  ('cajazeiras',),
#  ('garopaba',),
#  ('rio azul',),
#  ('dois corregos',),
#  ('sooretama',),
#  ('cruzeiro do oeste',),
#  ('nazare paulista',),
#  ('riversul',),
#  ('iguaracu',),
#  ('maracas',),
#  ('parana',),
#  ('reboucas',),
#  ('ametista do sul',),
#  ('itu',),
#  ('cacu',),
#  ('vespasiano',),
#  ('lindolfo collor',),
#  ('sao lourenco',),
#  ('santana do sobrado',),
#  ('cafelandia',),
#  ('ibiapina',),
#  ('schroeder',),
#  ('sao joao do oriente',),
#  ('matao',),
#  ('itanhandu',),
#  ('santo angelo',),
#  ('capinopolis',),
#  ('colatina',),
#  ('nova mutum',),
#  ('munhoz de melo',),
#  ('ibate',),
#  ('unai',),
#  ('medeiros neto',),
#  ('anta',),
#  ('ouroeste',),
#  ('central',),
#  ('nova independencia',),
#  ('itapema',),
#  ('sao jose do cedro',),
#  ('camutanga',),
#  ('ipumirim',),
#  ('cristalia',),
#  ('andira',),
#  ('panelas',),
#  ('comodoro',),
#  ('domingos martins',),
#  ('tangua',),
#  ('sao gotardo',),
#  ('araguaina',),
#  ('ilheus',),
#  ('louveira',),
#  ('imbituba',),
#  ('ouricuri',),
#  ('itatinga',),
#  ('santo cristo',),
#  ("arraial d'ajuda",),
#  ('piracanjuba',),
#  ('russas',),
#  ('lambari',),
#  ('vargem alta',),
#  ('sacra familia do tingua',),
#  ('assis chateaubriand',),
#  ('lago da pedra',),
#  ('unistalda',),
#  ('sao joao evangelista',),
#  ('paramirim',),
#  ('goias',),
#  ('paracuru',),
#  ('cruz alta',),
#  ('presidente bernardes',),
#  ('pains',),
#  ('sao goncalo do rio preto',),
#  ('jacinto machado',),
#  ('sobralia',),
#  ('maraba',),
#  ('paraibuna',),
#  ('toropi',),
#  ('jauru',),
#  ('cristalandia',),
#  ('castelo do piaui',),
#  ('ibipora',),
#  ('presidente dutra',),
#  ('vera cruz',),
#  ('paulo frontin',),
#  ...]

# %% [markdown]
# # 2. Count the number of orders placed in 2017.

# %%
query=""" select count(order_id) from orders where year(order_purchase_timestamp)=2018 """

cur.execute(query)
data=cur.fetchall()


"total orders placed in 2018 are ",data[0][0]
# Out:
# ('total orders placed in 2018 are ', 54011)

# %% [markdown]
# # Find the total sales per category.

# %%
query=""" select products.product_category category,sum(payments.payment_value) from products
join order_items
on products.product_id=order_items.product_id
join payments
on payments.order_id=order_items.order_id
group by category"""

cur.execute(query)
data=cur.fetchall()

df=pd.DataFrame(data,columns=["category","sales"])
df
# Out:
#                        category         sales
# 0                     perfumery  5.067387e+05
# 1          Furniture Decoration  1.430176e+06
# 2                     telephony  4.868821e+05
# 3                bed table bath  1.712554e+06
# 4                    automotive  8.522943e+05
# ..                          ...           ...
# 69               cds music dvds  1.199430e+03
# 70                   La Cuisine  2.913530e+03
# 71  Fashion Children's Clothing  7.856700e+02
# 72                     PC Gamer  2.174430e+03
# 73       insurance and services  3.245100e+02
#
# [74 rows x 2 columns]

# %% [markdown]
# # 5. Count the number of customers from each state.

# %%
query="""select customer_state,count(customer_id)
from customers group by customer_state"""

cur.execute(query)
data=cur.fetchall()

df=pd.DataFrame(data,columns=["state","customer_count"])
df=df.sort_values(by="customer_count",ascending=False)
plt.bar(df["state"],df["customer_count"])
plt.show()

# %% [markdown]
# # list seller city along with product they sold

# %%
query=""" select s.seller_city,p.product_category
from order_items oi
join sellers s on oi.seller_id=s.seller_id
join products p on oi.product_id=p.product_id"""

cur.execute(query)
data=cur.fetchall()

data
# Out:
# [('sao paulo', 'sport leisure'),
#  ('araraquara', 'Cool Stuff'),
#  ('ibitinga', 'Furniture Decoration'),
#  ('ibitinga', 'Furniture Decoration'),
#  ('sao paulo', 'HEALTH BEAUTY'),
#  ('ampere', 'housewares'),
#  ('ampere', 'housewares'),
#  ('ampere', 'housewares'),
#  ('ampere', 'housewares'),
#  ('franca', 'Fashion Underwear and Beach Fashion'),
#  ('sao paulo', 'Watches present'),
#  ('curitiba', 'Furniture Decoration'),
#  ('piracicaba', 'bed table bath'),
#  ('santo andre', 'perfumery'),
#  ('santo andre', 'perfumery'),
#  ('sao paulo', None),
#  ('sao paulo', 'electronics'),
#  ('rio de janeiro', 'toys'),
#  ('sao paulo', 'sport leisure'),
#  ('sao paulo', 'sport leisure'),
#  ('sao paulo', 'sport leisure'),
#  ('sao paulo', 'sport leisure'),
#  ('sao paulo', 'sport leisure'),
#  ('curitiba', 'sport leisure'),
#  ('brasilia', 'bed table bath'),
#  ('maua', 'housewares'),
#  ('sao paulo', 'HEALTH BEAUTY'),
#  ('sao paulo', 'electronics'),
#  ('ibitinga', 'bed table bath'),
#  ('ibitinga', 'Room Furniture'),
#  ('mogi guacu', 'Bags Accessories'),
#  ('brasilia', 'computer accessories'),
#  ('limeira', 'Cool Stuff'),
#  ('indaiatuba', 'Furniture Decoration'),
#  ('atibaia', 'Games consoles'),
#  ('sorocaba', 'sport leisure'),
#  ('curitiba', 'housewares'),
#  ('maringa', 'computer accessories'),
#  ('ribeirao preto', 'Watches present'),
#  ('ribeirao preto', 'Watches present'),
#  ('sao paulo', 'bed table bath'),
#  ('sao paulo', 'telephony'),
#  ('louveira', 'housewares'),
#  ('rio de janeiro', 'pet Shop'),
#  ('sao jose dos pinhais', 'Garden tools'),
#  ('balneario camboriu', 'electronics'),
#  ('presidente prudente', 'bed table bath'),
#  ('penapolis', 'automotive'),
#  ('brasilia', 'electronics'),
#  ('ribeirao preto', 'automotive'),
#  ('belo horizonte', 'computer accessories'),
#  ('ribeirao preto', None),
#  ('monte siao', 'Room Furniture'),
#  ('louveira', 'housewares'),
#  ('campo limpo paulista', 'toys'),
#  ('cascavel', 'sport leisure'),
#  ('indaiatuba', 'housewares'),
#  ('curitiba', 'toys'),
#  ('ponta grossa', None),
#  ('sao paulo', 'Cool Stuff'),
#  ('sao paulo', 'housewares'),
#  ('sao paulo', 'HEALTH BEAUTY'),
#  ('maringa', 'computer accessories'),
#  ('maringa', 'computer accessories'),
#  ('sao paulo', 'Watches present'),
#  ('limeira', 'Fashion Bags and Accessories'),
#  ('sao paulo', 'HEALTH BEAUTY'),
#  ('niteroi', 'Watches present'),
#  ('rolandia', 'Furniture Decoration'),
#  ('sao paulo', 'Games consoles'),
#  ('teixeira soares', 'Construction Tools Construction'),
#  ('ribeirao preto', 'sport leisure'),
#  ('piracicaba', 'bed table bath'),
#  ('maringa', 'computer accessories'),
#  ('monte siao', 'Room Furniture'),
#  ('joinville', 'housewares'),
#  ('joinville', 'housewares'),
#  ('joinville', 'housewares'),
#  ('sao paulo', 'Watches present'),
#  ('sao paulo', 'Watches present'),
#  ('pato branco', 'toys'),
#  ('pato branco', 'toys'),
#  ('sao paulo', 'technical books'),
#  ('sao paulo', 'Cool Stuff'),
#  ('sao paulo', 'Cool Stuff'),
#  ('sao paulo', 'Cool Stuff'),
#  ('sao paulo', 'Cool Stuff'),
#  ('joinville', 'sport leisure'),
#  ('sao bernardo do campo', 'bed table bath'),
#  ('volta redonda', 'Cool Stuff'),
#  ('sao paulo', 'toys'),
#  ('guarulhos', None),
#  ('riberao preto', 'computer accessories'),
#  ('limeira', 'Fashion Bags and Accessories'),
#  ('curitiba', 'sport leisure'),
#  ('garca', 'General Interest Books'),
#  ('blumenau', 'Construction Tools Construction'),
#  ('blumenau', 'Construction Tools Construction'),
#  ('blumenau', 'Construction Tools Construction'),
#  ('sao paulo', 'Cool Stuff'),
#  ('sao luis', 'HEALTH BEAUTY'),
#  ('ibitinga', 'bed table bath'),
#  ('sao paulo', 'toys'),
#  ('campo limpo paulista', 'stationary store'),
#  ('contagem', 'stationary store'),
#  ('contagem', 'stationary store'),
#  ('praia grande', 'home appliances'),
#  ('lauro de freitas', 'PCs'),
#  ('limeira', "Fashion Women's Clothing"),
#  ('ibitinga', 'bed table bath'),
#  ('brasilia', 'computer accessories'),
#  ('sao paulo', 'Watches present'),
#  ('brasilia', 'telephony'),
#  ('sao paulo', 'computer accessories'),
#  ('sao paulo', 'bed table bath'),
#  ('sao paulo', 'bed table bath'),
#  ('rio de janeiro', 'sport leisure'),
#  ('curitiba', 'Furniture Decoration'),
#  ('guarulhos', 'HOUSE PASTALS OVEN AND CAFE'),
#  ('osasco', 'ELECTRICES 2'),
#  ('cajamar', 'automotive'),
#  ('campina das missoes', 'computer accessories'),
#  ('campina das missoes', 'computer accessories'),
#  ('campina das missoes', 'computer accessories'),
#  ('ipaussu', 'housewares'),
#  ('cotia', 'automotive'),
#  ('rio de janeiro', 'sport leisure'),
#  ('rio de janeiro', 'sport leisure'),
#  ('lencois paulista', 'HEALTH BEAUTY'),
#  ('sao ludgero', 'telephony'),
#  ('sao paulo', 'Watches present'),
#  ('guarulhos', 'sport leisure'),
#  ('sorocaba', 'SIGNALIZATION AND SAFETY'),
#  ('sao paulo', 'HEALTH BEAUTY'),
#  ('campinas', 'Garden tools'),
#  ('sumare', 'Watches present'),
#  ('sao paulo', 'sport leisure'),
#  ('sao paulo', 'electronics'),
#  ('sao paulo', 'electronics'),
#  ('sao paulo', 'electronics'),
#  ('ibitinga', 'Furniture Decoration'),
#  ('jaragua do sul', 'Cool Stuff'),
#  ('maringa', 'computer accessories'),
#  ('maringa', 'computer accessories'),
#  ('maringa', 'computer accessories'),
#  ('maringa', 'computer accessories'),
#  ('brasilia df', 'fixed telephony'),
#  ('brasilia df', 'fixed telephony'),
#  ('ibitinga', 'bed table bath'),
#  ('ribeirao preto', 'HEALTH BEAUTY'),
#  ('guarulhos', 'housewares'),
#  ('santo andre', 'perfumery'),
#  ('santo andre', 'perfumery'),
#  ('sao paulo', 'Fashion Bags and Accessories'),
#  ('conselheiro lafaiete', 'Watches present'),
#  ('rio de janeiro', 'toys'),
#  ('guarulhos', 'HEALTH BEAUTY'),
#  ('santo andre', 'HEALTH BEAUTY'),
#  ('santo andre', 'HEALTH BEAUTY'),
#  ('santo andre', 'HEALTH BEAUTY'),
#  ('santo andre', 'HEALTH BEAUTY'),
#  ('santo andre', 'HEALTH BEAUTY'),
#  ('santo andre', 'HEALTH BEAUTY'),
#  ('jau', 'sport leisure'),
#  ('campo limpo paulista', 'toys'),
#  ('mirandopolis', 'Furniture Decoration'),
#  ('hortolandia', 'HEALTH BEAUTY'),
#  ('sao paulo', 'perfumery'),
#  ('sao paulo', 'telephony'),
#  ('sao paulo', 'Watches present'),
#  ('sao paulo', 'computer accessories'),
#  ('sao paulo', 'telephony'),
#  ('pedreira', 'housewares'),
#  ('limeira', 'Fashion Bags and Accessories'),
#  ('ribeirao preto', 'sport leisure'),
#  ('sao paulo', 'computer accessories'),
#  ('sao paulo', 'electronics'),
#  ('cascavel', 'housewares'),
#  ('praia grande', 'HEALTH BEAUTY'),
#  ('votorantim', 'bed table bath'),
#  ('sarandi', 'computer accessories'),
#  ('blumenau', 'ELECTRICES 2'),
#  ('sao paulo', 'stationary store'),
#  ('sao paulo', 'bed table bath'),
#  ('sao paulo', 'bed table bath'),
#  ('petropolis', 'perfumery'),
#  ('sao sebastiao', 'HEALTH BEAUTY'),
#  ('santo andre', 'telephony'),
#  ('belo horizonte', 'electronics'),
#  ('morrinhos', 'perfumery'),
#  ('riberao preto', 'telephony'),
#  ('hortolandia', 'HEALTH BEAUTY'),
#  ('piracicaba', 'bed table bath'),
#  ('piracicaba', 'bed table bath'),
#  ('belo horizonte', 'toys'),
#  ('sao paulo', 'toys'),
#  ('itaquaquecetuba', 'Furniture office'),
#  ('itaquaquecetuba', 'Furniture office'),
#  ('sao paulo', 'musical instruments'),
#  ('sao paulo', 'Furniture Decoration'),
#  ('uba', 'Furniture Decoration'),
#  ('belo horizonte', 'Bags Accessories'),
#  ('atibaia', 'automotive'),
#  ('curitiba', 'Furniture Decoration'),
#  ('sao paulo', 'HEALTH BEAUTY'),
#  ('sao bernardo do campo', 'sport leisure'),
#  ('sao paulo', 'automotive'),
#  ('maringa', 'electronics'),
#  ('ribeirao preto', 'housewares'),
#  ('belo horizonte', 'stationary store'),
#  ('betim', 'automotive'),
#  ('campinas', 'HEALTH BEAUTY'),
#  ('sao paulo', 'Furniture Decoration'),
#  ('votuporanga', 'House comfort'),
#  ('rio de janeiro', 'Cool Stuff'),
#  ('rio de janeiro', 'sport leisure'),
#  ('pedreira', 'housewares'),
#  ('teresina', 'automotive'),
#  ('itaquaquecetuba', 'Furniture office'),
#  ('piracicaba', 'bed table bath'),
#  ('franca', 'HEALTH BEAUTY'),
#  ('belo horizonte', 'automotive'),
#  ('sao paulo', 'perfumery'),
#  ('rio de janeiro', 'HEALTH BEAUTY'),
#  ('sao paulo', 'telephony'),
#  ('sao paulo', 'climatization'),
#  ('sao paulo', 'climatization'),
#  ('guariba', 'Watches present'),
#  ('caxias do sul', 'bed table bath'),
#  ('sao paulo', 'perfumery'),
#  ('itaquaquecetuba', 'Furniture office'),
#  ('itaquaquecetuba', 'Furniture office'),
#  ('birigui', 'sport leisure'),
#  ('salto', 'housewares'),
#  ('salto', 'housewares'),
#  ('salto', 'housewares'),
#  ('cajamar', 'automotive'),
#  ('belo horizonte', 'sport leisure'),
#  ('sao paulo', 'Furniture Decoration'),
#  ('sao paulo', 'Fashion Bags and Accessories'),
#  ('auriflama/sp', 'party articles'),
#  ('sao paulo', 'telephony'),
#  ('lajeado', 'bed table bath'),
#  ('guarulhos', 'Construction Tools Construction'),
#  ('sao paulo', 'Market Place'),
#  ('scao jose do rio pardo', 'toys'),
#  ('jaragua do sul', 'babies'),
#  ('sao jose do rio preto', 'Garden tools'),
#  ('sao jose do rio preto', 'Garden tools'),
#  ('sao jose do rio preto', 'Garden tools'),
#  ('sao jose do rio preto', 'Garden tools'),
#  ('sao jose do rio preto', 'Garden tools'),
#  ('sao jose do rio preto', 'Garden tools'),
#  ('foz do iguacu', 'bed table bath'),
#  ('belo horizonte', 'Games consoles'),
#  ('ibitinga', 'Furniture Decoration'),
#  ('rio do sul', 'sport leisure'),
#  ('ibitinga', 'bed table bath'),
#  ('rio de janeiro', 'sport leisure'),
#  ('monte siao', 'Furniture Decoration'),
#  ('santa barbara d´oeste', 'babies'),
#  ('curitiba', 'Agro Industria e Comercio'),
#  ('curitiba', 'Agro Industria e Comercio'),
#  ('curitiba', 'sport leisure'),
#  ('sao paulo', 'HEALTH BEAUTY'),
#  ('rolandia', 'computer accessories'),
#  ('sao paulo', 'Furniture Decoration'),
#  ('itapecerica da serra', 'automotive'),
#  ('sao paulo', 'toys'),
#  ('sao paulo', 'Watches present'),
#  ('pedreira', 'housewares'),
#  ('cariacica', 'Garden tools'),
#  ('sao paulo', 'telephony'),
#  ('petropolis', 'HEALTH BEAUTY'),
#  ('maringa', 'electronics'),
#  ('indaial', 'perfumery'),
#  ('ibitinga', 'Furniture Decoration'),
#  ('ponte nova', 'automotive'),
#  ('sao paulo', 'HEALTH BEAUTY'),
#  ('rio de janeiro', 'sport leisure'),
#  ('sao paulo', 'electronics'),
#  ('guarulhos', 'Industry Commerce and Business'),
#  ('poa', 'Garden tools'),
#  ('sao paulo', 'toys'),
#  ('riberao preto', 'perfumery'),
#  ('patos de minas', 'pet Shop'),
#  ('guariba', 'Games consoles'),
#  ('ipaussu', 'housewares'),
#  ('sao paulo', 'Furniture Decoration'),
#  ('franca', 'Watches present'),
#  ('sao paulo', 'sport leisure'),
#  ('sao paulo', 'HEALTH BEAUTY'),
#  ('sao paulo', 'telephony'),
#  ('cariacica', 'Garden tools'),
#  ('capivari', 'Construction Tools Construction'),
#  ('capivari', 'Construction Tools Construction'),
#  ('santo andre', 'HEALTH BEAUTY'),
#  ('santo andre', 'HEALTH BEAUTY'),
#  ('santo andre', 'HEALTH BEAUTY'),
#  ('santo andre', 'HEALTH BEAUTY'),
#  ('santo andre', 'HEALTH BEAUTY'),
#  ('foz do iguacu', 'bed table bath'),
#  ('itaquaquecetuba', 'Furniture office'),
#  ('ibitinga', 'Furniture Decoration'),
#  ('guarulhos', 'Watches present'),
#  ('praia grande', 'sport leisure'),
#  ('ribeirao das neves', 'automotive'),
#  ('ibitinga', 'babies'),
#  ('ibitinga', 'bed table bath'),
#  ('salto', 'pet Shop'),
#  ('aracatuba', 'Fashion Bags and Accessories'),
#  ('sao paulo', 'Cool Stuff'),
#  ('sao paulo', 'Cool Stuff'),
#  ('sao paulo', 'Cool Stuff'),
#  ('penapolis', 'automotive'),
#  ('bebedouro', 'automotive'),
#  ('sao paulo', 'telephony'),
#  ('sao paulo', 'telephony'),
#  ('sao paulo', 'musical instruments'),
#  ('sao paulo', 'Fashion Bags and Accessories'),
#  ('piracicaba', 'HEALTH BEAUTY'),
#  ('itaquaquecetuba', 'Furniture office'),
#  ('itaquaquecetuba', 'Furniture office'),
#  ('guariba', 'Watches present'),
#  ('porto alegre', 'climatization'),
#  ('porto alegre', 'climatization'),
#  ('sao paulo', 'stationary store'),
#  ('salto', 'home appliances'),
#  ('farroupilha', 'automotive'),
#  ('farroupilha', 'automotive'),
#  ('sao paulo', 'Furniture Decoration'),
#  ('sao paulo', 'Furniture Decoration'),
#  ('rio de janeiro', 'toys'),
#  ('ibitinga', 'House comfort'),
#  ('santos', 'telephony'),
#  ('santos', 'telephony'),
#  ('sao paulo', 'Watches present'),
#  ('sao paulo', 'Watches present'),
#  ('sao paulo', 'telephony'),
#  ('sao paulo', 'telephony'),
#  ('rio de janeiro', 'toys'),
#  ('cruzeiro', 'sport leisure'),
#  ('patos de minas', 'pet Shop'),
#  ('sao paulo', 'Furniture Decoration'),
#  ('sao paulo', 'Fashion Bags and Accessories'),
#  ('ribeirao preto', 'sport leisure'),
#  ('jacarei', 'pet Shop'),
#  ('araras', 'HEALTH BEAUTY'),
#  ('pedreira', 'housewares'),
#  ('santo andre', 'HEALTH BEAUTY'),
#  ('petropolis', 'perfumery'),
#  ('belo horizonte', 'HEALTH BEAUTY'),
#  ('santo andre', 'Furniture Decoration'),
#  ('ibitinga', 'House comfort'),
#  ('praia grande', 'home appliances'),
#  ('sao paulo', 'Furniture Decoration'),
#  ('sao paulo', 'Furniture Decoration'),
#  ('presidente prudente', 'Garden tools'),
#  ('francisco beltrao', None),
#  ('sao paulo', 'Construction Tools Garden'),
#  ('sao paulo', 'Construction Tools Garden'),
#  ('pirituba', 'sport leisure'),
#  ('pirituba', 'sport leisure'),
#  ('santos', 'computer accessories'),
#  ('santos', 'computer accessories'),
#  ('sao paulo', 'Fashion Bags and Accessories'),
#  ('ibitinga', 'bed table bath'),
#  ('ibitinga', 'bed table bath'),
#  ('sao paulo', 'telephony'),
#  ('ribeirao preto', 'Watches present'),
#  ('sao goncalo', 'Watches present'),
#  ('pedro leopoldo', 'pet Shop'),
#  ('penapolis', 'Fashion Calcados'),
#  ('maringa', 'computer accessories'),
#  ('maringa', 'computer accessories'),
#  ('sao paulo', 'pet Shop'),
#  ('sao paulo', 'pet Shop'),
#  ('belo horizonte', 'pet Shop'),
#  ('hortolandia', 'HEALTH BEAUTY'),
#  ('hortolandia', 'HEALTH BEAUTY'),
#  ('sao jose do rio preto', 'Garden tools'),
#  ('campinas', 'babies'),
#  ('petropolis', 'HEALTH BEAUTY'),
#  ('belo horizonte', 'Bags Accessories'),
#  ('lencois paulista', 'HEALTH BEAUTY'),
#  ('sao paulo', 'bed table bath'),
#  ('ipaussu', 'housewares'),
#  ('itapecerica da serra', 'telephony'),
#  ('jau', 'sport leisure'),
#  ('salto', 'Casa Construcao'),
#  ('sao paulo', 'party articles'),
#  ('rolandia', 'pet Shop'),
#  ('maua', 'HEALTH BEAUTY'),
#  ('sao paulo', 'electronics'),
#  ('rio do sul', 'sport leisure'),
#  ('rio do sul', 'sport leisure'),
#  ('ibitinga', 'bed table bath'),
#  ('sao ludgero', 'computer accessories'),
#  ('ibitinga', 'bed table bath'),
#  ('praia grande', 'home appliances'),
#  ('sao paulo', 'stationary store'),
#  ('piracicaba', 'computer accessories'),
#  ('piracicaba', 'computer accessories'),
#  ('piracicaba', 'computer accessories'),
#  ('sao paulo', 'bed table bath'),
#  ('petropolis', 'perfumery'),
#  ('guarulhos', 'automotive'),
#  ('piracicaba', 'bed table bath'),
#  ('ribeirao preto', 'HEALTH BEAUTY'),
#  ('piracicaba', 'bed table bath'),
#  ('sao paulo', 'toys'),
#  ('rio de janeiro', 'toys'),
#  ('sao paulo', 'Furniture Decoration'),
#  ('sao jose dos campos', 'computer accessories'),
#  ('sao jose dos campos', 'Cool Stuff'),
#  ('sao paulo', 'Cool Stuff'),
#  ('petropolis', 'perfumery'),
#  ('rio de janeiro', None),
#  ('sao paulo', 'telephony'),
#  ('sao paulo', 'Furniture Kitchen Service Area Dinner and Garden'),
#  ('sao paulo', 'HEALTH BEAUTY'),
#  ('sao paulo', 'toys'),
#  ('curitiba', 'bed table bath'),
#  ('ibitinga', 'bed table bath'),
#  ('ilicinea', 'computer accessories'),
#  ('ilicinea', 'computer accessories'),
#  ('ilicinea', 'computer accessories'),
#  ('ilicinea', 'computer accessories'),
#  ('ilicinea', 'computer accessories'),
#  ('ilicinea', 'computer accessories'),
#  ('jaragua do sul', 'musical instruments'),
#  ('sao paulo', 'electronics'),
#  ('piracicaba', 'bed table bath'),
#  ('sao paulo', 'HEALTH BEAUTY'),
#  ('rio de janeiro', 'sport leisure'),
#  ('uberlandia', 'electronics'),
#  ('santo andre', 'automotive'),
#  ('santo andre', 'automotive'),
#  ('santo andre', 'automotive'),
#  ('santo andre', 'automotive'),
#  ('mage', 'General Interest Books'),
#  ('rio de janeiro', 'sport leisure'),
#  ('ibitinga', 'bed table bath'),
#  ('ibitinga', 'bed table bath'),
#  ('pedreira', 'housewares'),
#  ('sao paulo', 'telephony'),
#  ('sao roque', 'Construction Tools Construction'),
#  ('limeira', 'housewares'),
#  ('araguari', 'housewares'),
#  ('petropolis', 'HEALTH BEAUTY'),
#  ('presidente prudente', 'telephony'),
#  ('ibitinga', 'House comfort'),
#  ('fronteira', 'HEALTH BEAUTY'),
#  ('sao paulo', 'housewares'),
#  ('sao paulo', 'automotive'),
#  ('registro', 'bed table bath'),
#  ('francisco beltrao', 'climatization'),
#  ('rio de janeiro', 'HEALTH BEAUTY'),
#  ('salto', 'sport leisure'),
#  ('sao paulo', 'bed table bath'),
#  ('curitiba', 'babies'),
#  ('sao paulo', 'Watches present'),
#  ('loanda', 'Garden tools'),
#  ('sao paulo', 'Industry Commerce and Business'),
#  ('sao paulo', 'Industry Commerce and Business'),
#  ('franca', 'HEALTH BEAUTY'),
#  ('pradopolis', 'Watches present'),
#  ('palhoca', 'Cool Stuff'),
#  ('pocos de caldas', 'housewares'),
#  ('novo horizonte', 'babies'),
#  ('tubarao', 'automotive'),
#  ('sao paulo', 'Furniture Decoration'),
#  ('sao paulo', 'telephony'),
#  ('araguari', 'toys'),
#  ('piracicaba', 'HEALTH BEAUTY'),
#  ('piracicaba', 'HEALTH BEAUTY'),
#  ('piracicaba', 'HEALTH BEAUTY'),
#  ('sao paulo', 'foods'),
#  ('sao paulo', 'foods'),
#  ('sao paulo', 'foods'),
#  ('sao paulo', 'foods'),
#  ('rio claro', 'Garden tools'),
#  ('rio claro', 'Garden tools'),
#  ('sao paulo', 'toys'),
#  ('andradas', 'toys'),
#  ('atibaia', 'automotive'),
#  ('sao paulo', 'computer accessories'),
#  ('sao paulo', 'computer accessories'),
#  ('coronel fabriciano', 'sport leisure'),
#  ('guarulhos', 'toys'),
#  ('itaquaquecetuba', 'Furniture office'),
#  ('guarulhos', 'Games consoles'),
#  ('maringa', 'computer accessories'),
#  ('botucatu', 'Furniture Decoration'),
#  ('botucatu', 'Furniture Decoration'),
#  ('sao paulo', 'electronics'),
#  ('sao paulo', 'sport leisure'),
#  ('sao paulo', 'computer accessories'),
#  ('nova friburgo', 'HEALTH BEAUTY'),
#  ('sao paulo', 'Furniture Decoration'),
#  ('sao paulo', 'Furniture Decoration'),
#  ('sao paulo', 'HEALTH BEAUTY'),
#  ('brasilia', 'telephony'),
#  ('santos', 'computer accessories'),
#  ('sao paulo', 'Construction Tools Construction'),
#  ('sao paulo', 'Construction Tools Construction'),
#  ('itaquaquecetuba', 'Furniture office'),
#  ('ibitinga', 'babies'),
#  ('ibitinga', 'bed table bath'),
#  ('ibitinga', 'bed table bath'),
#  ('ibitinga', 'bed table bath'),
#  ('ibitinga', 'bed table bath'),
#  ('ibitinga', 'bed table bath'),
#  ('ibitinga', 'bed table bath'),
#  ('ibitinga', 'bed table bath'),
#  ('ibitinga', 'bed table bath'),
#  ('sumare', 'Watches present'),
#  ('sao paulo', 'computer accessories'),
#  ('sao paulo', 'housewares'),
#  ('santo andre', 'perfumery'),
#  ('riberao preto', 'perfumery'),
#  ('brasilia', 'bed table bath'),
#  ('brasilia', 'bed table bath'),
#  ('limeira', 'stationary store'),
#  ('ibitinga', 'bed table bath'),
#  ('piracicaba', 'bed table bath'),
#  ('canoinhas', 'sport leisure'),
#  ('ibitinga', 'bed table bath'),
#  ('ibitinga', 'bed table bath'),
#  ('ibitinga', 'bed table bath'),
#  ('santos', 'pet Shop'),
#  ('guara', 'sport leisure'),
#  ('sao paulo', 'Fashion Bags and Accessories'),
#  ('sao paulo', 'Fashion Bags and Accessories'),
#  ('sao paulo', 'Fashion Bags and Accessories'),
#  ('capivari', 'toys'),
#  ('sao jose do rio preto', 'housewares'),
#  ('sao paulo', 'housewares'),
#  ('sao paulo', 'sport leisure'),
#  ('franca', 'HEALTH BEAUTY'),
#  ('rio de janeiro', 'sport leisure'),
#  ('atibaia', 'automotive'),
#  ('atibaia', 'automotive'),
#  ('sao paulo', 'HEALTH BEAUTY'),
#  ('sao paulo', 'HEALTH BEAUTY'),
#  ('salto', 'housewares'),
#  ('brejao', 'telephony'),
#  ('brejao', 'telephony'),
#  ('sumare', 'Watches present'),
#  ('sao paulo', 'telephony'),
#  ('guarulhos', None),
#  ('guarulhos', None),
#  ('itaquaquecetuba', 'Furniture office'),
#  ('ibitinga', 'bed table bath'),
#  ('ibitinga', 'bed table bath'),
#  ('campo limpo paulista', 'toys'),
#  ('sao paulo', 'toys'),
#  ('sete lagoas', 'Fashion Bags and Accessories'),
#  ('sinop', 'perfumery'),
#  ('sinop', 'perfumery'),
#  ('guarulhos', 'computer accessories'),
#  ('guarulhos', 'housewares'),
#  ('sao paulo', 'Bags Accessories'),
#  ('blumenau', 'computer accessories'),
#  ('montenegro', 'Cool Stuff'),
#  ('ibitinga', 'Furniture Decoration'),
#  ('ibitinga', 'Furniture Decoration'),
#  ('sao paulo', 'party articles'),
#  ('campo limpo paulista', 'stationary store'),
#  ('santana de parnaiba', 'telephony'),
#  ('sao paulo', 'telephony'),
#  ('petropolis', 'perfumery'),
#  ('belo horizonte', 'toys'),
#  ('belo horizonte', 'toys'),
#  ('belo horizonte', 'computer accessories'),
#  ('belo horizonte', 'computer accessories'),
#  ('sao paulo', 'Cool Stuff'),
#  ('sao paulo', 'telephony'),
#  ('sao paulo', 'stationary store'),
#  ('curitiba', 'sport leisure'),
#  ('curitiba', 'sport leisure'),
#  ('ibitinga', 'Furniture Decoration'),
#  ('ibitinga', 'Furniture Decoration'),
#  ('piracicaba', 'HEALTH BEAUTY'),
#  ('piracicaba', 'HEALTH BEAUTY'),
#  ('petropolis', 'HEALTH BEAUTY'),
#  ('assis', 'Fashion Underwear and Beach Fashion'),
#  ('sao paulo', 'telephony'),
#  ('sao paulo', 'Watches present'),
#  ('belo horizonte', 'computer accessories'),
#  ('sao paulo', 'toys'),
#  ('cariacica', 'Garden tools'),
#  ('cariacica', 'Garden tools'),
#  ('sao paulo', 'Cool Stuff'),
#  ('guarulhos', 'automotive'),
#  ('cascavel', 'Furniture Decoration'),
#  ('salto', 'Garden tools'),
#  ('taboao da serra', None),
#  ('taboao da serra', None),
#  ('salto', 'Art'),
#  ('salto', 'Art'),
#  ('salto', 'Art'),
#  ('limeira', 'Fashion Bags and Accessories'),
#  ('maringa', 'computer accessories'),
#  ('sao paulo', 'toys'),
#  ('sorocaba', 'musical instruments'),
#  ('ibitinga', 'bed table bath'),
#  ('jacarei', 'automotive'),
#  ('cascavel', 'song'),
#  ('rio de janeiro', 'babies'),
#  ('betim', 'HEALTH BEAUTY'),
#  ('piracicaba', 'bed table bath'),
#  ('itaquaquecetuba', 'Furniture office'),
#  ('guarulhos', 'Industry Commerce and Business'),
#  ('ribeirao preto', 'Watches present'),
#  ('guariba', 'Watches present'),
#  ('ribeirao preto', 'Watches present'),
#  ('sao paulo', 'computer accessories'),
#  ('sao ludgero', 'housewares'),
#  ('sao paulo', 'Watches present'),
#  ('borda da mata', 'Bags Accessories'),
#  ('sao carlos', 'perfumery'),
#  ('itaquaquecetuba', 'Furniture office'),
#  ('massaranduba', 'housewares'),
#  ('itaquaquecetuba', 'Furniture office'),
#  ('joinville', 'toys'),
#  ('tupa', 'babies'),
#  ('itaquaquecetuba', 'Furniture office'),
#  ('campinas', 'telephony'),
#  ('itatiba', 'babies'),
#  ('londrina', 'musical instruments'),
#  ('sao paulo', 'computer accessories'),
#  ('bebedouro', 'automotive'),
#  ('sao paulo', 'babies'),
#  ('araguari', 'housewares'),
#  ('curitiba', 'Agro Industria e Comercio'),
#  ('sao paulo', 'Furniture Decoration'),
#  ('sao paulo', 'Watches present'),
#  ('patos de minas', 'pet Shop'),
#  ('santos', 'computer accessories'),
#  ('ibitinga', 'bed table bath'),
#  ('ibitinga', 'bed table bath'),
#  ('ibitinga', 'bed table bath'),
#  ('ibitinga', 'bed table bath'),
#  ('cuiaba', 'HEALTH BEAUTY'),
#  ('sao paulo', 'telephony'),
#  ('sao paulo', 'Construction Tools Illumination'),
#  ('hortolandia', 'HEALTH BEAUTY'),
#  ('hortolandia', 'HEALTH BEAUTY'),
#  ('sao paulo', 'Games consoles'),
#  ('sao paulo', 'housewares'),
#  ('rio de janeiro', 'HEALTH BEAUTY'),
#  ('ibitinga', 'bed table bath'),
#  ('sao  paulo', 'computer accessories'),
#  ('sao paulo', 'automotive'),
#  ('uba', 'Furniture Kitchen Service Area Dinner and Garden'),
#  ('echapora', 'HEALTH BEAUTY'),
#  ('sao paulo', 'telephony'),
#  ('guariba', 'Watches present'),
#  ('sao paulo', 'pet Shop'),
#  ('araguari', 'housewares'),
#  ('caucaia', 'foods'),
#  ('sao paulo', None),
#  ('belo horizonte', 'HEALTH BEAUTY'),
#  ('guarulhos', 'bed table bath'),
#  ('petropolis', 'perfumery'),
#  ('sao goncalo', 'computer accessories'),
#  ('sao paulo', 'telephony'),
#  ('curitiba', 'sport leisure'),
#  ('timbo', "Fashion Men's Clothing"),
#  ('campo limpo paulista', 'stationary store'),
#  ('contagem', 'sport leisure'),
#  ('poa', 'bed table bath'),
#  ('sao paulo', 'sport leisure'),
#  ('sao paulo', 'Construction Tools Construction'),
#  ('sao paulo', 'Furniture Decoration'),
#  ('sao paulo', 'Furniture Decoration'),
#  ('salto', 'housewares'),
#  ('maringa', 'computer accessories'),
#  ('santa rosa de viterbo', 'Garden tools'),
#  ('ibitinga', 'bed table bath'),
#  ('ibitinga', 'bed table bath'),
#  ('pedreira', 'housewares'),
#  ('curitiba', 'perfumery'),
#  ('osasco', 'automotive'),
#  ('sao paulo', "Fashion Men's Clothing"),
#  ('sao paulo', 'toys'),
#  ('umuarama', 'perfumery'),
#  ('salto', 'sport leisure'),
#  ('sao paulo', 'Furniture Kitchen Service Area Dinner and Garden'),
#  ('dracena', 'Games consoles'),
#  ('dracena', 'Games consoles'),
#  ('sao paulo', 'technical books'),
#  ('sao paulo', 'CONSTRUCTION SECURITY TOOLS'),
#  ('porto ferreira', 'Furniture Decoration'),
#  ('limeira', 'Furniture Decoration'),
#  ('sao paulo', 'technical books'),
#  ('sao paulo', None),
#  ('sao paulo', 'housewares'),
#  ('sao paulo', 'automotive'),
#  ('sao paulo', 'Furniture Decoration'),
#  ('sao paulo', 'Furniture Decoration'),
#  ('sao paulo', 'Furniture Decoration'),
#  ('sao paulo', 'Furniture Decoration'),
#  ('sao paulo', 'Furniture Decoration'),
#  ('itauna', 'computer accessories'),
#  ('ibitinga', 'bed table bath'),
#  ('santo andre', 'Furniture Decoration'),
#  ('joinville', 'bed table bath'),
#  ('scao jose do rio pardo', 'toys'),
#  ('ibitinga', 'Furniture Decoration'),
#  ('sao paulo', 'sport leisure'),
#  ('ibitinga', 'bed table bath'),
#  ('ibitinga', 'bed table bath'),
#  ('sao paulo', 'computer accessories'),
#  ('sao bernardo do campo', 'Furniture Kitchen Service Area Dinner and Garden'),
#  ('sao paulo', 'bed table bath'),
#  ('sao paulo', 'Cool Stuff'),
#  ('santa barbara d´oeste', 'Bags Accessories'),
#  ('ji parana', 'automotive'),
#  ('sao paulo', 'telephony'),
#  ('sao paulo', 'pet Shop'),
#  ('ibitinga', 'bed table bath'),
#  ('curitiba', 'Garden tools'),
#  ('penapolis', 'Furniture Kitchen Service Area Dinner and Garden'),
#  ('curitiba', 'sport leisure'),
#  ('sao luis', 'HEALTH BEAUTY'),
#  ('sao luis', 'HEALTH BEAUTY'),
#  ('ibitinga', 'bed table bath'),
#  ('ibitinga', 'bed table bath'),
#  ('maua', None),
#  ('sao paulo', 'Cool Stuff'),
#  ('gama', 'Fashion Bags and Accessories'),
#  ('sao jose do rio preto', 'Garden tools'),
#  ('sao jose do rio preto', 'Garden tools'),
#  ('sao jose do rio preto', 'Garden tools'),
#  ('sao jose do rio preto', 'Garden tools'),
#  ('sao jose do rio preto', 'Garden tools'),
#  ('sao jose do rio preto', 'Garden tools'),
#  ('sao jose do rio preto', 'Garden tools'),
#  ('sao jose do rio preto', 'Garden tools'),
#  ('sao jose do rio preto', 'Garden tools'),
#  ('sao jose do rio preto', 'Garden tools'),
#  ('sao jose do rio preto', 'Garden tools'),
#  ('borda da mata', 'Bags Accessories'),
#  ('borda da mata', 'Bags Accessories'),
#  ('borda da mata', 'Bags Accessories'),
#  ('vicente de carvalho', 'sport leisure'),
#  ('sao paulo', 'bed table bath'),
#  ('marilia', 'climatization'),
#  ('guariba', 'audio'),
#  ('itaquaquecetuba', 'Furniture office'),
#  ('itaquaquecetuba', 'Furniture office'),
#  ('itatiba', 'babies'),
#  ('maua', 'babies'),
#  ('salto', 'HEALTH BEAUTY'),
#  ('guarulhos', 'Furniture Decoration'),
#  ('santo andre', 'perfumery'),
#  ('santo andre', 'perfumery'),
#  ('santo andre', 'perfumery'),
#  ('santo andre', 'HEALTH BEAUTY'),
#  ('santo andre', 'HEALTH BEAUTY'),
#  ('santo andre', 'HEALTH BEAUTY'),
#  ('blumenau', 'Watches present'),
#  ('juiz de fora', 'babies'),
#  ('guariba', 'Watches present'),
#  ('congonhas', 'computer accessories'),
#  ('sao paulo', 'Furniture Decoration'),
#  ('sao paulo', 'Furniture Decoration'),
#  ('sao paulo', 'Furniture Decoration'),
#  ('sao paulo', 'Furniture Decoration'),
#  ('sao paulo', 'Furniture Decoration'),
#  ('ibitinga', 'bed table bath'),
#  ('maua', 'toys'),
#  ('sao paulo', 'housewares'),
#  ('curitiba', 'General Interest Books'),
#  ('riberao preto', 'computer accessories'),
#  ('sao paulo', 'housewares'),
#  ('petropolis', 'perfumery'),
#  ('petropolis', 'perfumery'),
#  ('arapongas', 'babies'),
#  ('sao paulo', 'computer accessories'),
#  ('sao paulo', 'housewares'),
#  ('sao paulo', 'housewares'),
#  ('porto alegre', 'computer accessories'),
#  ('cascavel', 'musical instruments'),
#  ('blumenau', 'Watches present'),
#  ('brasilia', 'computer accessories'),
#  ('sao jose dos campos', 'computer accessories'),
#  ('sumare', 'Watches present'),
#  ('sao paulo', 'computer accessories'),
#  ('sao paulo', 'computer accessories'),
#  ('sao paulo', 'Furniture Decoration'),
#  ('sao paulo', 'Furniture Decoration'),
#  ('sao paulo', 'Furniture Decoration'),
#  ('sao paulo', 'Furniture Decoration'),
#  ('sao paulo', 'Furniture Decoration'),
#  ('sao paulo', 'Furniture Decoration'),
#  ('sao paulo', 'Furniture Decoration'),
#  ('sao paulo', 'Furniture Decoration'),
#  ('sao paulo', 'stationary store'),
#  ('praia grande', 'home appliances'),
#  ('cascavel', 'Games consoles'),
#  ('rio de janeiro', 'toys'),
#  ('ribeirao preto', 'computer accessories'),
#  ('ribeirao preto', 'computer accessories'),
#  ('ibitinga', 'bed table bath'),
#  ('varzea paulista', 'computer accessories'),
#  ('varzea paulista', 'computer accessories'),
#  ('jacarei', 'Games consoles'),
#  ('barueri', 'Construction Tools Construction'),
#  ('sao paulo', 'computer accessories'),
#  ('franca', 'perfumery'),
#  ('itaquaquecetuba', 'Furniture Decoration'),
#  ('cascavel', 'Watches present'),
#  ('franca', 'telephony'),
#  ('aparecida de goiania', 'automotive'),
#  ('coronel fabriciano', 'sport leisure'),
#  ('jales', 'Furniture Decoration'),
#  ('contagem', 'housewares'),
#  ('contagem', 'housewares'),
#  ('campo limpo paulista', 'stationary store'),
#  ('campo limpo paulista', 'stationary store'),
#  ('sao paulo', 'HEALTH BEAUTY'),
#  ('sao bernardo do campo', 'housewares'),
#  ('sao bernardo do campo', 'electronics'),
#  ('andradas', 'Cool Stuff'),
#  ('ibitinga', 'bed table bath'),
#  ('ibitinga', 'bed table bath'),
#  ('ibitinga', 'bed table bath'),
#  ('lauro de freitas', 'telephony'),
#  ('lauro de freitas', 'telephony'),
#  ('lauro de freitas', 'telephony'),
#  ('lauro de freitas', 'telephony'),
#  ('lauro de freitas', 'telephony'),
#  ('lauro de freitas', 'telephony'),
#  ('lauro de freitas', 'telephony'),
#  ('lauro de freitas', 'telephony'),
#  ('lauro de freitas', 'telephony'),
#  ('lauro de freitas', 'telephony'),
#  ('blumenau', 'Furniture office'),
#  ('sao paulo', 'Furniture Decoration'),
#  ('sao paulo', 'babies'),
#  ('curitiba', 'sport leisure'),
#  ('ribeirao preto', 'computer accessories'),
#  ('sao paulo', 'HEALTH BEAUTY'),
#  ('rio de janeiro', 'pet Shop'),
#  ('valinhos', 'perfumery'),
#  ('campinas', 'perfumery'),
#  ('sao paulo', 'Fashion Bags and Accessories'),
#  ('petropolis', 'HEALTH BEAUTY'),
#  ('jacarei', 'computer accessories'),
#  ('marilia', 'CONSTRUCTION SECURITY TOOLS'),
#  ('vicente de carvalho', 'sport leisure'),
#  ('pirituba', 'sport leisure'),
#  ('sao bernardo do campo', 'HEALTH BEAUTY'),
#  ('sao bernardo do campo', 'HEALTH BEAUTY'),
#  ('sao paulo', 'computer accessories'),
#  ('sao paulo', 'computer accessories'),
#  ('taboao da serra', 'perfumery'),
#  ('sao paulo', 'Watches present'),
#  ('divinopolis', 'automotive'),
#  ('sao paulo', 'computer accessories'),
#  ('maringa', 'computer accessories'),
#  ('ibitinga', 'bed table bath'),
#  ('sao paulo', 'housewares'),
#  ('belo horizonte', 'computer accessories'),
#  ('franca', 'HEALTH BEAUTY'),
#  ('contagem', 'stationary store'),
#  ('sao paulo', 'telephony'),
#  ('sao paulo', 'telephony'),
#  ('araras', 'electrostile'),
#  ('araras', 'electrostile'),
#  ('sao paulo', 'automotive'),
#  ('santo andre', 'bed table bath'),
#  ('jaboticabal', 'housewares'),
#  ('sao paulo', 'electronics'),
#  ('catanduva', 'babies'),
#  ('itaquaquecetuba', 'Furniture office'),
#  ('ibitinga', 'bed table bath'),
#  ('osasco', 'telephony'),
#  ('sao paulo', 'stationary store'),
#  ('sao paulo', 'housewares'),
#  ('recife', 'computer accessories'),
#  ('belo horizonte', 'computer accessories'),
#  ('belo horizonte', 'computer accessories'),
#  ('praia grande', 'sport leisure'),
#  ('itaquaquecetuba', 'HEALTH BEAUTY'),
#  ('campo limpo paulista', 'stationary store'),
#  ('votorantim', 'Garden tools'),
#  ('ibitinga', 'bed table bath'),
#  ('garca', 'General Interest Books'),
#  ('pedreira', 'housewares'),
#  ('pedreira', 'housewares'),
#  ('sao paulo', 'babies'),
#  ('sao paulo', 'babies'),
#  ('campo largo', 'sport leisure'),
#  ('itajai', 'stationary store'),
#  ('ibitinga', 'bed table bath'),
#  ('piracicaba', 'automotive'),
#  ('campinas', 'pet Shop'),
#  ('guara', 'sport leisure'),
#  ('braganca paulista', 'HEALTH BEAUTY'),
#  ('pilar do sul', 'housewares'),
#  ('belo horizonte', 'computer accessories'),
#  ('goiania', 'housewares'),
#  ('sao paulo', 'CONSTRUCTION SECURITY TOOLS'),
#  ('sarandi', 'computer accessories'),
#  ('sarandi', 'computer accessories'),
#  ('sarandi', 'computer accessories'),
#  ('sao paulo', 'Watches present'),
#  ('sao paulo', 'HEALTH BEAUTY'),
#  ('betim', 'HEALTH BEAUTY'),
#  ('praia grande', 'HEALTH BEAUTY'),
#  ('praia grande', 'HEALTH BEAUTY'),
#  ('baependi', 'housewares'),
#  ('sao paulo', 'Watches present'),
#  ('taboao da serra', 'HEALTH BEAUTY'),
#  ('sao paulo', 'telephony'),
#  ('santo andre', 'perfumery'),
#  ('cascavel', 'Watches present'),
#  ('santo andre', 'HEALTH BEAUTY'),
#  ('ibitinga', 'Furniture Decoration'),
#  ('curitiba', 'housewares'),
#  ('tiradentes', 'Furniture Decoration'),
#  ('araraquara', 'computer accessories'),
#  ('sao paulo', 'HEALTH BEAUTY'),
#  ('itapecerica da serra', 'telephony'),
#  ('curitiba', 'toys'),
#  ('maua', 'Cool Stuff'),
#  ('borda da mata', 'sport leisure'),
#  ('ribeirao preto', 'HEALTH BEAUTY'),
#  ('sao jose dos campos', 'computer accessories'),
#  ('sao jose dos campos', 'computer accessories'),
#  ('lages', 'Garden tools'),
#  ('amparo', 'Furniture Decoration'),
#  ('sao paulo', 'electronics'),
#  ('mogi das cruzes', 'HEALTH BEAUTY'),
#  ('mogi das cruzes', 'HEALTH BEAUTY'),
#  ('ibitinga', 'bed table bath'),
#  ('itatiba', 'babies'),
#  ('sao paulo', 'Cool Stuff'),
#  ('toledo', 'telephony'),
#  ('sao paulo', 'bed table bath'),
#  ('piracicaba', 'bed table bath'),
#  ('ribeirao preto', 'bed table bath'),
#  ('ribeirao preto', 'bed table bath'),
#  ('flores da cunha', 'pet Shop'),
#  ('sao bernardo do campo', 'automotive'),
#  ('teresopolis', 'HEALTH BEAUTY'),
#  ('franca', 'telephony'),
#  ('mineiros do tiete', 'HEALTH BEAUTY'),
#  ('campo limpo paulista', 'stationary store'),
#  ('assis', 'perfumery'),
#  ('sao paulo', 'Watches present'),
#  ('sao paulo', 'Watches present'),
#  ('maringa', 'electronics'),
#  ('maringa', 'electronics'),
#  ('maringa', 'electronics'),
#  ('parai', 'computer accessories'),
#  ('belo horizonte', 'computer accessories'),
#  ('sao paulo', 'Furniture Decoration'),
#  ('sao paulo', 'Furniture Decoration'),
#  ('sao paulo', 'Furniture Decoration'),
#  ('guarulhos', 'automotive'),
#  ('rio grande', 'Garden tools'),
#  ('caxias do sul', 'Furniture Kitchen Service Area Dinner and Garden'),
#  ('sumare', 'Watches present'),
#  ('maringa', 'computer accessories'),
#  ('maringa', 'computer accessories'),
#  ('piracicaba', 'bed table bath'),
#  ('cananeia', 'telephony'),
#  ('barueri', 'electronics'),
#  ('sao paulo', 'Construction Tools Illumination'),
#  ('sao paulo', 'Construction Tools Illumination'),
#  ('sao bernardo do campo', 'sport leisure'),
#  ('fernandopolis', 'Furniture Decoration'),
#  ('itatiba', 'babies'),
#  ('curitiba', 'HEALTH BEAUTY'),
#  ('curitiba', 'HEALTH BEAUTY'),
#  ('cascavel', 'Furniture Decoration'),
#  ('ibitinga', 'bed table bath'),
#  ('blumenau', 'sport leisure'),
#  ('belo horizonte', 'HEALTH BEAUTY'),
#  ('porto alegre', 'Furniture Decoration'),
#  ('sp', 'computer accessories'),
#  ('sorocaba', 'SIGNALIZATION AND SAFETY'),
#  ('campo limpo paulista', 'stationary store'),
#  ('sao paulo', 'sport leisure'),
#  ('piracicaba', 'bed table bath'),
#  ('piracicaba', 'bed table bath'),
#  ('sao paulo', 'Cool Stuff'),
#  ('sao paulo', 'Cool Stuff'),
#  ('sao paulo', 'Cool Stuff'),
#  ('sao paulo', 'telephony'),
#  ('sao paulo', 'Watches present'),
#  ('sao paulo', 'Watches present'),
#  ('sao paulo', 'Watches present'),
#  ('sao paulo', 'Watches present'),
#  ('cruzeiro', 'sport leisure'),
#  ...]

# %% [markdown]
# # Calculate the number of orders per month in 2018.

# %%
query="""select monthname(order_purchase_timestamp)months,count(order_id)
from orders where year(order_purchase_timestamp)=2018
group by months"""

cur.execute(query)
data=cur.fetchall()

df=pd.DataFrame(data,columns=["months","order_count"])
sns.barplot(x=df["months"],y=df["order_count"], data=df)
plt.xticks(rotation=30)
plt.show()
